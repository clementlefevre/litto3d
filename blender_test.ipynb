# %% [markdown]
# <a href="https://colab.research.google.com/github/clementlefevre/litto3d/blob/master/blender_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
blender_file = '/content/drive/My\\ Drive/blender/berlin_mitte.blend'
blender_config = '/content/drive/My\\ Drive/blender/config.py'

# %%
# !apt install blender
# !apt install libboost-all-dev
# !apt install libgl1-mesa-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   blender-data fonts-dejavu fonts-dejavu-core fonts-dejavu-extra libblosc1
#   libglew2.0 libjemalloc1 liblog4cplus-1.1-9 libopencolorio1v5
#   libopenimageio1.7 libopenvdb5.0 libraw16 libspnav0 libtinyxml2.6.2v5
#   libyaml-cpp0.5v5
# Suggested packages:
#   glew-utils spacenavd
# The following NEW packages will be installed:
#   blender blender-data fonts-dejavu fonts-dejavu-core fonts-dejavu-extra
#   libblosc1 libglew2.0 libjemalloc1 liblog4cplus-1.1-9 libopencolorio1v5
#   libopenimageio1.7 libopenvdb5.0 libraw16 libspnav0 libtinyxml2.6.2v5
#   libyaml-cpp0.5v5
# 0 upgraded, 16 newly installed, 0 to remove and 7 not upgraded.
# Need to get 45.2 MB of archives.
# After this operation, 224 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 blender-data all 2.79.b+dfsg0-1ubuntu1.18.04.1 [12.2 MB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-dejavu-core all 2.37-1 [1,041 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-dejavu-extra all 2.37-1 [1,953 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-dejavu all 2.37-1 [3,130 B]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libglew2.0 amd64 2.0.0-5 [140 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libjemalloc1 amd64 3.6.0-11 [82.4 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libtinyxml2.6.2v5 amd64 2.6.2-4 [29.7 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libyaml-cpp0.5v5 amd64 0.5.2-4ubuntu1 [150 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopencolorio1v5 amd64 1.1.0~dfsg0-1 [307 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libraw16 amd64 0.18.8-1ubuntu0.3 [264 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopenimageio1.7 amd64 1.7.17~dfsg0-1ubuntu2 [1,715 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libblosc1 amd64 1.14.2+ds1-1 [31.4 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/universe amd64 liblog4cplus-1.1-9 amd64 1.1.2-3.2 [139 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopenvdb5.0 amd64 5.0.0-1 [556 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libspnav0 amd64 0.2.3-1 [8,552 B]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 blender amd64 2.79.b+dfsg0-1ubuntu1.18.04.1 [26.6 MB]
# Fetched 45.2 MB in 1s (71.0 MB/s)
# Selecting previously unselected package blender-data.
# (Reading database ... 131331 files and directories currently installed.)
# Preparing to unpack .../00-blender-data_2.79.b+dfsg0-1ubuntu1.18.04.1_all.deb ...
# Unpacking blender-data (2.79.b+dfsg0-1ubuntu1.18.04.1) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../01-fonts-dejavu-core_2.37-1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../02-fonts-dejavu-extra_2.37-1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-1) ...
# Selecting previously unselected package fonts-dejavu.
# Preparing to unpack .../03-fonts-dejavu_2.37-1_all.deb ...
# Unpacking fonts-dejavu (2.37-1) ...
# Selecting previously unselected package libglew2.0:amd64.
# Preparing to unpack .../04-libglew2.0_2.0.0-5_amd64.deb ...
# Unpacking libglew2.0:amd64 (2.0.0-5) ...
# Selecting previously unselected package libjemalloc1.
# Preparing to unpack .../05-libjemalloc1_3.6.0-11_amd64.deb ...
# Unpacking libjemalloc1 (3.6.0-11) ...
# Selecting previously unselected package libtinyxml2.6.2v5:amd64.
# Preparing to unpack .../06-libtinyxml2.6.2v5_2.6.2-4_amd64.deb ...
# Unpacking libtinyxml2.6.2v5:amd64 (2.6.2-4) ...
# Selecting previously unselected package libyaml-cpp0.5v5:amd64.
# Preparing to unpack .../07-libyaml-cpp0.5v5_0.5.2-4ubuntu1_amd64.deb ...
# Unpacking libyaml-cpp0.5v5:amd64 (0.5.2-4ubuntu1) ...
# Selecting previously unselected package libopencolorio1v5.
# Preparing to unpack .../08-libopencolorio1v5_1.1.0~dfsg0-1_amd64.deb ...
# Unpacking libopencolorio1v5 (1.1.0~dfsg0-1) ...
# Selecting previously unselected package libraw16:amd64.
# Preparing to unpack .../09-libraw16_0.18.8-1ubuntu0.3_amd64.deb ...
# Unpacking libraw16:amd64 (0.18.8-1ubuntu0.3) ...
# Selecting previously unselected package libopenimageio1.7.
# Preparing to unpack .../10-libopenimageio1.7_1.7.17~dfsg0-1ubuntu2_amd64.deb ...
# Unpacking libopenimageio1.7 (1.7.17~dfsg0-1ubuntu2) ...
# Selecting previously unselected package libblosc1.
# Preparing to unpack .../11-libblosc1_1.14.2+ds1-1_amd64.deb ...
# Unpacking libblosc1 (1.14.2+ds1-1) ...
# Selecting previously unselected package liblog4cplus-1.1-9.
# Preparing to unpack .../12-liblog4cplus-1.1-9_1.1.2-3.2_amd64.deb ...
# Unpacking liblog4cplus-1.1-9 (1.1.2-3.2) ...
# Selecting previously unselected package libopenvdb5.0.
# Preparing to unpack .../13-libopenvdb5.0_5.0.0-1_amd64.deb ...
# Unpacking libopenvdb5.0 (5.0.0-1) ...
# Selecting previously unselected package libspnav0.
# Preparing to unpack .../14-libspnav0_0.2.3-1_amd64.deb ...
# Unpacking libspnav0 (0.2.3-1) ...
# Selecting previously unselected package blender.
# Preparing to unpack .../15-blender_2.79.b+dfsg0-1ubuntu1.18.04.1_amd64.deb ...
# Unpacking blender (2.79.b+dfsg0-1ubuntu1.18.04.1) ...
# Setting up libblosc1 (1.14.2+ds1-1) ...
# Setting up libspnav0 (0.2.3-1) ...
# Setting up libtinyxml2.6.2v5:amd64 (2.6.2-4) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Setting up libjemalloc1 (3.6.0-11) ...
# Setting up fonts-dejavu-core (2.37-1) ...
# Setting up liblog4cplus-1.1-9 (1.1.2-3.2) ...
# Setting up blender-data (2.79.b+dfsg0-1ubuntu1.18.04.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Setting up libglew2.0:amd64 (2.0.0-5) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Setting up libyaml-cpp0.5v5:amd64 (0.5.2-4ubuntu1) ...
# Setting up fonts-dejavu-extra (2.37-1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Setting up libraw16:amd64 (0.18.8-1ubuntu0.3) ...
# Setting up libopenvdb5.0 (5.0.0-1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# Setting up fonts-dejavu (2.37-1) ...
# Setting up libopencolorio1v5 (1.1.0~dfsg0-1) ...
# Setting up libopenimageio1.7 (1.7.17~dfsg0-1ubuntu2) ...
# Setting up blender (2.79.b+dfsg0-1ubuntu1.18.04.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libboost-all-dev is already the newest version (1.65.1.0ubuntu1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 7 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libgl1-mesa-dev is already the newest version (19.0.2-1ubuntu1.1~18.04.1).
# libgl1-mesa-dev set to manually installed.
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 7 not upgraded.

# %%
# !blender $blender_file -b -P $blender_config  --use-extension 1 	-noaudio -nojoystick -E CYCLES -t 0   --use-extension 1
# Out:
# Read blend: /content/drive/My Drive/blender/berlin_mitte.blend
# ptxas warning : Value of threads per SM for entry kernel_cuda_bake is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry kernel_cuda_shader is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry kernel_cuda_convert_to_half_float is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry kernel_cuda_convert_to_byte is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry kernel_cuda_path_trace is out of range. .minnctapersm will be ignored
# ptxas info    : 0 bytes gmem, 1760 bytes cmem[3]
# ptxas info    : Compiling entry function 'kernel_cuda_bake' for 'sm_75'
# ptxas info    : Function properties for kernel_cuda_bake
#     39120 bytes stack frame, 8 bytes spill stores, 4 bytes spill loads
# ptxas info    : Used 128 registers, 392 bytes cmem[0], 1080 bytes cmem[2]
# ptxas info    : Function properties for _Z11brick_noisei
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z11cmj_permutejjj
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z11svm_checker6float3
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z11svm_voronoi19NodeVoronoiColoring6float3
#     0 bytes stack frame, 108 bytes spill stores, 132 bytes spill loads
# ptxas info    : Function properties for _Z12light_sampleP13KernelGlobalsffff6float3iP11LightSample
#     0 bytes stack frame, 4 bytes spill stores, 4 bytes spill loads
# ptxas info    : Function properties for _Z14kernel_path_aoP13KernelGlobalsP10ShaderDataS2_P12PathRadianceP9PathStatePj6float3S8_
#     0 bytes stack frame, 28 bytes spill stores, 112 bytes spill loads
# ptxas info    : Function properties for _Z14shader_bsdf_aoP13KernelGlobalsP10ShaderDatafP6float3
#     0 bytes stack frame, 12 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z14shadow_blockedP13KernelGlobalsP10ShaderDataP9PathStateP3RayP6float3
#     0 bytes stack frame, 124 bytes spill stores, 360 bytes spill loads
# ptxas info    : Function properties for _Z14svm_eval_nodesP13KernelGlobalsP10ShaderDataP9PathState10ShaderTypei
#     0 bytes stack frame, 688 bytes spill stores, 344 bytes spill loads
# ptxas info    : Function properties for _Z15direct_emissionP13KernelGlobalsP10ShaderDataS2_P11LightSampleP9PathStateP3RayP8BsdfEvalPbf
#     0 bytes stack frame, 32 bytes spill stores, 56 bytes spill loads
# ptxas info    : Function properties for _Z15path_state_nextP13KernelGlobalsP9PathStatei
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z15rgb_ramp_lookupP13KernelGlobalsifbbi
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z16noise_turbulence6float3fi
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z17area_light_sample6float3PS_S_S_ffb
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z17lamp_light_sampleP13KernelGlobalsiff6float3P11LightSample
#     0 bytes stack frame, 4 bytes spill stores, 12 bytes spill loads
# ptxas info    : Function properties for _Z17shader_bssrdf_sumP10ShaderDataP6float3Pf
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z17svm_node_geometryP13KernelGlobalsP10ShaderDataPfjj
#     0 bytes stack frame, 8 bytes spill stores, 16 bytes spill loads
# ptxas info    : Function properties for _Z18background_map_pdfP13KernelGlobals6float3
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z18noise_musgrave_fBm6float3fff
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z18shader_bsdf_sampleP13KernelGlobalsP10ShaderDataffP8BsdfEvalP6float3P13differential3Pf
#     0 bytes stack frame, 208 bytes spill stores, 28 bytes spill loads
# ptxas info    : Function properties for _Z18shader_eval_volumeP13KernelGlobalsP10ShaderDataP9PathStateP11VolumeStacki13ShaderContext
#     0 bytes stack frame, 32 bytes spill stores, 44 bytes spill loads
# ptxas info    : Function properties for _Z18triangle_intersectP13KernelGlobalsP12Intersection6float3S3_jii
#     0 bytes stack frame, 12 bytes spill stores, 24 bytes spill loads
# ptxas info    : Function properties for _Z19camera_world_to_ndcP13KernelGlobalsP10ShaderData6float3
#     0 bytes stack frame, 8 bytes spill stores, 8 bytes spill loads
# ptxas info    : Function properties for _Z19indirect_backgroundP13KernelGlobalsP10ShaderDataP9PathStateP3Ray
#     0 bytes stack frame, 16 bytes spill stores, 16 bytes spill loads
# ptxas info    : Function properties for _Z20direct_emissive_evalP13KernelGlobalsP10ShaderDataP11LightSampleP9PathState6float313differential3ff
#     0 bytes stack frame, 28 bytes spill stores, 36 bytes spill loads
# ptxas info    : Function properties for _Z20kernel_bake_evaluateP13KernelGlobalsP5uint4P6float414ShaderEvalTypeiiii
#     0 bytes stack frame, 580 bytes spill stores, 996 bytes spill loads
# ptxas info    : Function properties for _Z20kernel_path_indirectP13KernelGlobalsP10ShaderDataS2_PjP3Ray6float3iP9PathStateP12PathRadiance
#     0 bytes stack frame, 340 bytes spill stores, 784 bytes spill loads
# ptxas info    : Function properties for _Z20kernel_volume_shadowP13KernelGlobalsP10ShaderDataP9PathStateP3RayP6float3
#     0 bytes stack frame, 328 bytes spill stores, 216 bytes spill loads
# ptxas info    : Function properties for _Z20patch_map_find_patchP13KernelGlobalsiiff
#     0 bytes stack frame, 8 bytes spill stores, 8 bytes spill loads
# ptxas info    : Function properties for _Z20shader_emissive_evalP13KernelGlobalsP10ShaderData
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z21background_map_sampleP13KernelGlobalsffPf
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z21background_portal_pdfP13KernelGlobals6float3S1_iPb
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z21direction_to_panoramaP13KernelGlobals6float3
#     0 bytes stack frame, 8 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z21shader_merge_closuresP10ShaderData
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z21shader_setup_from_rayP13KernelGlobalsP10ShaderDataPK12IntersectionPK3Ray
#     0 bytes stack frame, 72 bytes spill stores, 72 bytes spill loads
# ptxas info    : Function properties for _Z21svm_node_attr_bump_dxP13KernelGlobalsP10ShaderDataPf5uint4
#     0 bytes stack frame, 16 bytes spill stores, 48 bytes spill loads
# ptxas info    : Function properties for _Z21svm_node_attr_bump_dyP13KernelGlobalsP10ShaderDataPf5uint4
#     0 bytes stack frame, 16 bytes spill stores, 48 bytes spill loads
# ptxas info    : Function properties for _Z22BVH_bvh_intersect_hairP13KernelGlobalsPK3RayP12IntersectionjPjff
#     0 bytes stack frame, 12 bytes spill stores, 8 bytes spill loads
# ptxas info    : Function properties for _Z22indirect_lamp_emissionP13KernelGlobalsP10ShaderDataP9PathStateP3RayP6float3
#     0 bytes stack frame, 100 bytes spill stores, 108 bytes spill loads
# ptxas info    : Function properties for _Z22path_radiance_accum_aoP12PathRadianceP9PathState6float3S3_S3_S3_
#     0 bytes stack frame, 0 bytes spill stores, 16 bytes spill loads
# ptxas info    : Function properties for _Z23_shader_bsdf_multi_evalP13KernelGlobalsP10ShaderData6float3PfiP8BsdfEvalff
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z23kernel_volume_integrateP13KernelGlobalsP9PathStateP10ShaderDataP3RayP12PathRadianceP6float3Pjb
#     0 bytes stack frame, 1118 bytes spill stores, 804 bytes spill loads
# ptxas info    : Function properties for _Z23subsurface_scatter_evalP10ShaderDataP13ShaderClosureffb
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z24BVH_bvh_intersect_motionP13KernelGlobalsPK3RayP12Intersectionj
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z24shader_setup_from_sampleP13KernelGlobalsP10ShaderData6float3S3_S3_iiiffffbi
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z25kernel_path_volume_bounceP13KernelGlobalsPjP10ShaderDataP6float3P9PathStateP12PathRadianceP3Ray
#     0 bytes stack frame, 132 bytes spill stores, 72 bytes spill loads
# ptxas info    : Function properties for _Z25motion_triangle_intersectP13KernelGlobalsP12Intersection6float3S3_fjii
#     0 bytes stack frame, 76 bytes spill stores, 88 bytes spill loads
# ptxas info    : Function properties for _Z25path_radiance_accum_lightP12PathRadianceP9PathState6float3P8BsdfEvalS3_fb
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z25primitive_attribute_floatP13KernelGlobalsPK10ShaderData19AttributeDescriptorPfS5_
#     0 bytes stack frame, 4 bytes spill stores, 4 bytes spill loads
# ptxas info    : Function properties for _Z26kernel_path_surface_bounceP13KernelGlobalsPjP10ShaderDataP6float3P9PathStateP12PathRadianceP3Ray
#     0 bytes stack frame, 4 bytes spill stores, 8 bytes spill loads
# ptxas info    : Function properties for _Z26primitive_attribute_float3P13KernelGlobalsPK10ShaderData19AttributeDescriptorP6float3S6_
#     0 bytes stack frame, 4 bytes spill stores, 8 bytes spill loads
# ptxas info    : Function properties for _Z26triangle_refine_subsurfaceP13KernelGlobalsP10ShaderDataPK12IntersectionPK3Ray
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z26volume_normalized_positionP13KernelGlobalsPK10ShaderData6float3
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z27indirect_primitive_emissionP13KernelGlobalsP10ShaderDatafif
#     0 bytes stack frame, 12 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z27path_radiance_clamp_and_sumP13KernelGlobalsP12PathRadiance
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z28BVH_bvh_intersect_instancingP13KernelGlobalsPK3RayP12Intersectionj
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z28motion_triangle_shader_setupP13KernelGlobalsP10ShaderDataPK12IntersectionPK3Rayb
#     0 bytes stack frame, 96 bytes spill stores, 96 bytes spill loads
# ptxas info    : Function properties for _Z28noise_musgrave_multi_fractal6float3fff
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z28shader_setup_from_subsurfaceP13KernelGlobalsP10ShaderDataPK12IntersectionPK3Ray
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z29BVH_bvh_intersect_hair_motionP13KernelGlobalsPK3RayP12IntersectionjPjff
#     0 bytes stack frame, 12 bytes spill stores, 8 bytes spill loads
# ptxas info    : Function properties for _Z29noise_musgrave_hetero_terrain6float3ffff
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z29subd_triangle_attribute_floatP13KernelGlobalsPK10ShaderData19AttributeDescriptorPfS5_
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z29triangle_intersect_subsurfaceP13KernelGlobalsP22SubsurfaceIntersection6float3S3_iifPji
#     0 bytes stack frame, 12 bytes spill stores, 28 bytes spill loads
# ptxas info    : Function properties for _Z30kernel_path_subsurface_scatterP13KernelGlobalsP10ShaderDataS2_P12PathRadianceP9PathStatePjP3RayP6float3P22SubsurfaceIndirectRays
#     0 bytes stack frame, 144 bytes spill stores, 380 bytes spill loads
# ptxas info    : Function properties for _Z30subd_triangle_attribute_float3P13KernelGlobalsPK10ShaderData19AttributeDescriptorP6float3S6_
#     0 bytes stack frame, 48 bytes spill stores, 44 bytes spill loads
# ptxas info    : Function properties for _Z30subsurface_scatter_multi_setupP13KernelGlobalsP22SubsurfaceIntersectioniP10ShaderDataP9PathStateiP13ShaderClosureb
#     0 bytes stack frame, 28 bytes spill stores, 36 bytes spill loads
# ptxas info    : Function properties for _Z32_shader_bsdf_multi_eval_branchedP13KernelGlobalsP10ShaderData6float3P8BsdfEvalfb
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z32path_state_rng_light_terminationP13KernelGlobalsPjPK9PathState
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z33kernel_path_surface_connect_lightP13KernelGlobalsPjP10ShaderDataS3_6float3P9PathStateP12PathRadiance
#     0 bytes stack frame, 132 bytes spill stores, 212 bytes spill loads
# ptxas info    : Function properties for _Z34direction_to_equirectangular_range6float36float4
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z34object_fetch_transform_motion_testP13KernelGlobalsifP9Transform
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z34subsurface_scatter_multi_intersectP13KernelGlobalsP22SubsurfaceIntersectionP10ShaderDataP13ShaderClosurePjffb
#     0 bytes stack frame, 120 bytes spill stores, 132 bytes spill loads
# ptxas info    : Function properties for _Z35kernel_branched_path_surface_bounceP13KernelGlobalsPjP10ShaderDataPK13ShaderClosureiiP6float3P9PathStateP12PathRadianceP3Rayf
#     0 bytes stack frame, 1240 bytes spill stores, 352 bytes spill loads
# ptxas info    : Function properties for _Z35noise_musgrave_hybrid_multi_fractal6float3fffff
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z35noise_musgrave_ridged_multi_fractal6float3fffff
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z35path_branched_rng_light_terminationP13KernelGlobalsPjPK9PathStateii
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z35shadow_blocked_transparent_all_loopP13KernelGlobalsP10ShaderDataP9PathStateiP3RayP12IntersectionjP6float3
#     0 bytes stack frame, 178 bytes spill stores, 212 bytes spill loads
# ptxas info    : Function properties for _Z39kernel_branched_path_subsurface_scatterP13KernelGlobalsP10ShaderDataS2_S2_P12PathRadianceP9PathStatePjP3Ray6float3
#     0 bytes stack frame, 308 bytes spill stores, 572 bytes spill loads
# ptxas info    : Function properties for _Z42kernel_branched_path_surface_connect_lightP13KernelGlobalsPjP10ShaderDataS3_P9PathState6float3fP12PathRadiancei
#     0 bytes stack frame, 244 bytes spill stores, 864 bytes spill loads
# ptxas info    : Function properties for _Z43kernel_branched_path_surface_indirect_lightP13KernelGlobalsPjP10ShaderDataS3_S3_6float3fP9PathStateP12PathRadiance
#     0 bytes stack frame, 148 bytes spill stores, 152 bytes spill loads
# ptxas info    : Function properties for _Z6perlinfff
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z7svm_mix7NodeMixf6float3S0_
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z8svm_wave12NodeWaveType16NodeWaveProfiles6float3fff
#     0 bytes stack frame, 4 bytes spill stores, 4 bytes spill loads
# ptxas info    : Function properties for _Z9cellnoise6float3
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z9svm_brick6float3ffffffifi
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z9svm_magic6float3if
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z9wireframeP13KernelGlobalsP10ShaderDatafiP6float3
#     0 bytes stack frame, 48 bytes spill stores, 48 bytes spill loads
# ptxas info    : Function properties for lgammaf
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Compiling entry function 'kernel_cuda_shader' for 'sm_75'
# ptxas info    : Function properties for kernel_cuda_shader
#     8016 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 190 registers, 396 bytes cmem[0], 220 bytes cmem[2]
# ptxas info    : Function properties for _Z11brick_noisei
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z11svm_checker6float3
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z11svm_voronoi19NodeVoronoiColoring6float3
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z14svm_eval_nodesP13KernelGlobalsP10ShaderDataP9PathState10ShaderTypei
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z15rgb_ramp_lookupP13KernelGlobalsifbbi
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z16noise_turbulence6float3fi
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z17svm_node_geometryP13KernelGlobalsP10ShaderDataPfjj
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z18noise_musgrave_fBm6float3fff
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z19camera_world_to_ndcP13KernelGlobalsP10ShaderData6float3
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z20patch_map_find_patchP13KernelGlobalsiiff
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z21direction_to_panoramaP13KernelGlobals6float3
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z21svm_node_attr_bump_dxP13KernelGlobalsP10ShaderDataPf5uint4
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z21svm_node_attr_bump_dyP13KernelGlobalsP10ShaderDataPf5uint4
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z24shader_setup_from_sampleP13KernelGlobalsP10ShaderData6float3S3_S3_iiiffffbi
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z25primitive_attribute_floatP13KernelGlobalsPK10ShaderData19AttributeDescriptorPfS5_
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z26primitive_attribute_float3P13KernelGlobalsPK10ShaderData19AttributeDescriptorP6float3S6_
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z26volume_normalized_positionP13KernelGlobalsPK10ShaderData6float3
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z28noise_musgrave_multi_fractal6float3fff
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z29noise_musgrave_hetero_terrain6float3ffff
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z29subd_triangle_attribute_floatP13KernelGlobalsPK10ShaderData19AttributeDescriptorPfS5_
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z30subd_triangle_attribute_float3P13KernelGlobalsPK10ShaderData19AttributeDescriptorP6float3S6_
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z34direction_to_equirectangular_range6float36float4
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z35noise_musgrave_hybrid_multi_fractal6float3fffff
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z35noise_musgrave_ridged_multi_fractal6float3fffff
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z6perlinfff
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z7svm_mix7NodeMixf6float3S0_
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z8svm_wave12NodeWaveType16NodeWaveProfiles6float3fff
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z9cellnoise6float3
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z9svm_brick6float3ffffffifi
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z9svm_magic6float3if
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z9wireframeP13KernelGlobalsP10ShaderDatafiP6float3
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Compiling entry function 'kernel_cuda_convert_to_half_float' for 'sm_75'
# ptxas info    : Function properties for kernel_cuda_convert_to_half_float
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 12 registers, 396 bytes cmem[0]
# ptxas info    : Compiling entry function 'kernel_cuda_convert_to_byte' for 'sm_75'
# ptxas info    : Function properties for kernel_cuda_convert_to_byte
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 17 registers, 396 bytes cmem[0]
# ptxas info    : Compiling entry function 'kernel_cuda_branched_path_trace' for 'sm_75'
# ptxas info    : Function properties for kernel_cuda_branched_path_trace
#     36176 bytes stack frame, 688 bytes spill stores, 984 bytes spill loads
# ptxas info    : Used 64 registers, 396 bytes cmem[0], 1008 bytes cmem[2]
# ptxas info    : Function properties for _Z11brick_noisei
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z11cmj_permutejjj
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z11svm_checker6float3
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z11svm_voronoi19NodeVoronoiColoring6float3
#     0 bytes stack frame, 108 bytes spill stores, 132 bytes spill loads
# ptxas info    : Function properties for _Z12light_sampleP13KernelGlobalsffff6float3iP11LightSample
#     0 bytes stack frame, 4 bytes spill stores, 4 bytes spill loads
# ptxas info    : Function properties for _Z13camera_sampleP13KernelGlobalsiifffffP3Ray
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z14kernel_path_aoP13KernelGlobalsP10ShaderDataS2_P12PathRadianceP9PathStatePj6float3S8_
#     0 bytes stack frame, 52 bytes spill stores, 124 bytes spill loads
# ptxas info    : Function properties for _Z14shader_bsdf_aoP13KernelGlobalsP10ShaderDatafP6float3
#     0 bytes stack frame, 12 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z14shadow_blockedP13KernelGlobalsP10ShaderDataP9PathStateP3RayP6float3
#     0 bytes stack frame, 240 bytes spill stores, 604 bytes spill loads
# ptxas info    : Function properties for _Z14svm_eval_nodesP13KernelGlobalsP10ShaderDataP9PathState10ShaderTypei
#     0 bytes stack frame, 740 bytes spill stores, 628 bytes spill loads
# ptxas info    : Function properties for _Z15direct_emissionP13KernelGlobalsP10ShaderDataS2_P11LightSampleP9PathStateP3RayP8BsdfEvalPbf
#     0 bytes stack frame, 96 bytes spill stores, 160 bytes spill loads
# ptxas info    : Function properties for _Z15path_state_nextP13KernelGlobalsP9PathStatei
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z15rgb_ramp_lookupP13KernelGlobalsifbbi
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z16noise_turbulence6float3fi
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z17area_light_sample6float3PS_S_S_ffb
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z17lamp_light_sampleP13KernelGlobalsiff6float3P11LightSample
#     0 bytes stack frame, 4 bytes spill stores, 12 bytes spill loads
# ptxas info    : Function properties for _Z17shader_bssrdf_sumP10ShaderDataP6float3Pf
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z17svm_node_geometryP13KernelGlobalsP10ShaderDataPfjj
#     0 bytes stack frame, 12 bytes spill stores, 24 bytes spill loads
# ptxas info    : Function properties for _Z18background_map_pdfP13KernelGlobals6float3
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z18noise_musgrave_fBm6float3fff
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z18shader_bsdf_sampleP13KernelGlobalsP10ShaderDataffP8BsdfEvalP6float3P13differential3Pf
#     0 bytes stack frame, 244 bytes spill stores, 88 bytes spill loads
# ptxas info    : Function properties for _Z18shader_eval_volumeP13KernelGlobalsP10ShaderDataP9PathStateP11VolumeStacki13ShaderContext
#     0 bytes stack frame, 48 bytes spill stores, 72 bytes spill loads
# ptxas info    : Function properties for _Z18triangle_intersectP13KernelGlobalsP12Intersection6float3S3_jii
#     0 bytes stack frame, 12 bytes spill stores, 24 bytes spill loads
# ptxas info    : Function properties for _Z19camera_world_to_ndcP13KernelGlobalsP10ShaderData6float3
#     0 bytes stack frame, 8 bytes spill stores, 8 bytes spill loads
# ptxas info    : Function properties for _Z19indirect_backgroundP13KernelGlobalsP10ShaderDataP9PathStateP3Ray
#     0 bytes stack frame, 48 bytes spill stores, 44 bytes spill loads
# ptxas info    : Function properties for _Z19kernel_write_resultP13KernelGlobalsPfiP12PathRadiancefb
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z20direct_emissive_evalP13KernelGlobalsP10ShaderDataP11LightSampleP9PathState6float313differential3ff
#     0 bytes stack frame, 108 bytes spill stores, 80 bytes spill loads
# ptxas info    : Function properties for _Z20kernel_path_indirectP13KernelGlobalsP10ShaderDataS2_PjP3Ray6float3iP9PathStateP12PathRadiance
#     0 bytes stack frame, 564 bytes spill stores, 1484 bytes spill loads
# ptxas info    : Function properties for _Z20kernel_volume_shadowP13KernelGlobalsP10ShaderDataP9PathStateP3RayP6float3
#     0 bytes stack frame, 352 bytes spill stores, 280 bytes spill loads
# ptxas info    : Function properties for _Z20patch_map_find_patchP13KernelGlobalsiiff
#     0 bytes stack frame, 8 bytes spill stores, 8 bytes spill loads
# ptxas info    : Function properties for _Z20shader_emissive_evalP13KernelGlobalsP10ShaderData
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z21background_map_sampleP13KernelGlobalsffPf
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z21background_portal_pdfP13KernelGlobals6float3S1_iPb
#     0 bytes stack frame, 12 bytes spill stores, 4 bytes spill loads
# ptxas info    : Function properties for _Z21direction_to_panoramaP13KernelGlobals6float3
#     0 bytes stack frame, 8 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z21panorama_to_directionP13KernelGlobalsff
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z21shader_merge_closuresP10ShaderData
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z21shader_setup_from_rayP13KernelGlobalsP10ShaderDataPK12IntersectionPK3Ray
#     0 bytes stack frame, 148 bytes spill stores, 164 bytes spill loads
# ptxas info    : Function properties for _Z21svm_node_attr_bump_dxP13KernelGlobalsP10ShaderDataPf5uint4
#     0 bytes stack frame, 32 bytes spill stores, 104 bytes spill loads
# ptxas info    : Function properties for _Z21svm_node_attr_bump_dyP13KernelGlobalsP10ShaderDataPf5uint4
#     0 bytes stack frame, 32 bytes spill stores, 104 bytes spill loads
# ptxas info    : Function properties for _Z22BVH_bvh_intersect_hairP13KernelGlobalsPK3RayP12IntersectionjPjff
#     0 bytes stack frame, 188 bytes spill stores, 208 bytes spill loads
# ptxas info    : Function properties for _Z22indirect_lamp_emissionP13KernelGlobalsP10ShaderDataP9PathStateP3RayP6float3
#     0 bytes stack frame, 112 bytes spill stores, 160 bytes spill loads
# ptxas info    : Function properties for _Z22path_radiance_accum_aoP12PathRadianceP9PathState6float3S3_S3_S3_
#     0 bytes stack frame, 0 bytes spill stores, 28 bytes spill loads
# ptxas info    : Function properties for _Z23_shader_bsdf_multi_evalP13KernelGlobalsP10ShaderData6float3PfiP8BsdfEvalff
#     0 bytes stack frame, 60 bytes spill stores, 80 bytes spill loads
# ptxas info    : Function properties for _Z23kernel_volume_integrateP13KernelGlobalsP9PathStateP10ShaderDataP3RayP12PathRadianceP6float3Pjb
#     0 bytes stack frame, 1166 bytes spill stores, 1004 bytes spill loads
# ptxas info    : Function properties for _Z23subsurface_scatter_evalP10ShaderDataP13ShaderClosureffb
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z24BVH_bvh_intersect_motionP13KernelGlobalsPK3RayP12Intersectionj
#     0 bytes stack frame, 12 bytes spill stores, 12 bytes spill loads
# ptxas info    : Function properties for _Z24kernel_volume_stack_initP13KernelGlobalsP10ShaderDataPK9PathStatePK3RayP11VolumeStack
#     0 bytes stack frame, 212 bytes spill stores, 424 bytes spill loads
# ptxas info    : Function properties for _Z24kernel_write_data_passesP13KernelGlobalsPfP12PathRadianceP10ShaderDataiP9PathState6float3
#     0 bytes stack frame, 96 bytes spill stores, 272 bytes spill loads
# ptxas info    : Function properties for _Z24shader_setup_from_sampleP13KernelGlobalsP10ShaderData6float3S3_S3_iiiffffbi
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z25kernel_path_volume_bounceP13KernelGlobalsPjP10ShaderDataP6float3P9PathStateP12PathRadianceP3Ray
#     0 bytes stack frame, 132 bytes spill stores, 68 bytes spill loads
# ptxas info    : Function properties for _Z25motion_triangle_intersectP13KernelGlobalsP12Intersection6float3S3_fjii
#     0 bytes stack frame, 92 bytes spill stores, 104 bytes spill loads
# ptxas info    : Function properties for _Z25path_radiance_accum_lightP12PathRadianceP9PathState6float3P8BsdfEvalS3_fb
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z25primitive_attribute_floatP13KernelGlobalsPK10ShaderData19AttributeDescriptorPfS5_
#     0 bytes stack frame, 4 bytes spill stores, 4 bytes spill loads
# ptxas info    : Function properties for _Z26kernel_path_surface_bounceP13KernelGlobalsPjP10ShaderDataP6float3P9PathStateP12PathRadianceP3Ray
#     0 bytes stack frame, 36 bytes spill stores, 96 bytes spill loads
# ptxas info    : Function properties for _Z26primitive_attribute_float3P13KernelGlobalsPK10ShaderData19AttributeDescriptorP6float3S6_
#     0 bytes stack frame, 16 bytes spill stores, 20 bytes spill loads
# ptxas info    : Function properties for _Z26triangle_refine_subsurfaceP13KernelGlobalsP10ShaderDataPK12IntersectionPK3Ray
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z26volume_normalized_positionP13KernelGlobalsPK10ShaderData6float3
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z27indirect_primitive_emissionP13KernelGlobalsP10ShaderDatafif
#     0 bytes stack frame, 12 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z27path_radiance_clamp_and_sumP13KernelGlobalsP12PathRadiance
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z28BVH_bvh_intersect_instancingP13KernelGlobalsPK3RayP12Intersectionj
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z28motion_triangle_shader_setupP13KernelGlobalsP10ShaderDataPK12IntersectionPK3Rayb
#     0 bytes stack frame, 132 bytes spill stores, 132 bytes spill loads
# ptxas info    : Function properties for _Z28noise_musgrave_multi_fractal6float3fff
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z28shader_setup_from_subsurfaceP13KernelGlobalsP10ShaderDataPK12IntersectionPK3Ray
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z29BVH_bvh_intersect_hair_motionP13KernelGlobalsPK3RayP12IntersectionjPjff
#     0 bytes stack frame, 168 bytes spill stores, 236 bytes spill loads
# ptxas info    : Function properties for _Z29noise_musgrave_hetero_terrain6float3ffff
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z29subd_triangle_attribute_floatP13KernelGlobalsPK10ShaderData19AttributeDescriptorPfS5_
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z29triangle_intersect_subsurfaceP13KernelGlobalsP22SubsurfaceIntersection6float3S3_iifPji
#     0 bytes stack frame, 12 bytes spill stores, 28 bytes spill loads
# ptxas info    : Function properties for _Z30subd_triangle_attribute_float3P13KernelGlobalsPK10ShaderData19AttributeDescriptorP6float3S6_
#     0 bytes stack frame, 260 bytes spill stores, 396 bytes spill loads
# ptxas info    : Function properties for _Z30subsurface_scatter_multi_setupP13KernelGlobalsP22SubsurfaceIntersectioniP10ShaderDataP9PathStateiP13ShaderClosureb
#     0 bytes stack frame, 72 bytes spill stores, 112 bytes spill loads
# ptxas info    : Function properties for _Z32_shader_bsdf_multi_eval_branchedP13KernelGlobalsP10ShaderData6float3P8BsdfEvalfb
#     0 bytes stack frame, 4 bytes spill stores, 24 bytes spill loads
# ptxas info    : Function properties for _Z32path_state_rng_light_terminationP13KernelGlobalsPjPK9PathState
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z34direction_to_equirectangular_range6float36float4
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z34object_fetch_transform_motion_testP13KernelGlobalsifP9Transform
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z34subsurface_scatter_multi_intersectP13KernelGlobalsP22SubsurfaceIntersectionP10ShaderDataP13ShaderClosurePjffb
#     0 bytes stack frame, 376 bytes spill stores, 580 bytes spill loads
# ptxas info    : Function properties for _Z35kernel_branched_path_surface_bounceP13KernelGlobalsPjP10ShaderDataPK13ShaderClosureiiP6float3P9PathStateP12PathRadianceP3Rayf
#     0 bytes stack frame, 1556 bytes spill stores, 380 bytes spill loads
# ptxas info    : Function properties for _Z35noise_musgrave_hybrid_multi_fractal6float3fffff
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z35noise_musgrave_ridged_multi_fractal6float3fffff
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z35path_branched_rng_light_terminationP13KernelGlobalsPjPK9PathStateii
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z35shadow_blocked_transparent_all_loopP13KernelGlobalsP10ShaderDataP9PathStateiP3RayP12IntersectionjP6float3
#     0 bytes stack frame, 680 bytes spill stores, 880 bytes spill loads
# ptxas info    : Function properties for _Z39kernel_branched_path_subsurface_scatterP13KernelGlobalsP10ShaderDataS2_S2_P12PathRadianceP9PathStatePjP3Ray6float3
#     0 bytes stack frame, 420 bytes spill stores, 696 bytes spill loads
# ptxas info    : Function properties for _Z42kernel_branched_path_surface_connect_lightP13KernelGlobalsPjP10ShaderDataS3_P9PathState6float3fP12PathRadiancei
#     0 bytes stack frame, 288 bytes spill stores, 872 bytes spill loads
# ptxas info    : Function properties for _Z43kernel_branched_path_surface_indirect_lightP13KernelGlobalsPjP10ShaderDataS3_S3_6float3fP9PathStateP12PathRadiance
#     0 bytes stack frame, 172 bytes spill stores, 188 bytes spill loads
# ptxas info    : Function properties for _Z6perlinfff
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z7svm_mix7NodeMixf6float3S0_
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z8svm_wave12NodeWaveType16NodeWaveProfiles6float3fff
#     0 bytes stack frame, 4 bytes spill stores, 4 bytes spill loads
# ptxas info    : Function properties for _Z9cellnoise6float3
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z9svm_brick6float3ffffffifi
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z9svm_magic6float3if
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z9wireframeP13KernelGlobalsP10ShaderDatafiP6float3
#     0 bytes stack frame, 48 bytes spill stores, 48 bytes spill loads
# ptxas info    : Function properties for lgammaf
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Compiling entry function 'kernel_cuda_path_trace' for 'sm_75'
# ptxas info    : Function properties for kernel_cuda_path_trace
#     25600 bytes stack frame, 672 bytes spill stores, 1012 bytes spill loads
# ptxas info    : Used 64 registers, 396 bytes cmem[0], 924 bytes cmem[2]
# ptxas info    : Function properties for _Z11brick_noisei
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z11cmj_permutejjj
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z11svm_checker6float3
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z11svm_voronoi19NodeVoronoiColoring6float3
#     0 bytes stack frame, 108 bytes spill stores, 132 bytes spill loads
# ptxas info    : Function properties for _Z12light_sampleP13KernelGlobalsffff6float3iP11LightSample
#     0 bytes stack frame, 4 bytes spill stores, 4 bytes spill loads
# ptxas info    : Function properties for _Z13camera_sampleP13KernelGlobalsiifffffP3Ray
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z14kernel_path_aoP13KernelGlobalsP10ShaderDataS2_P12PathRadianceP9PathStatePj6float3S8_
#     0 bytes stack frame, 52 bytes spill stores, 148 bytes spill loads
# ptxas info    : Function properties for _Z14shader_bsdf_aoP13KernelGlobalsP10ShaderDatafP6float3
#     0 bytes stack frame, 12 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z14shadow_blockedP13KernelGlobalsP10ShaderDataP9PathStateP3RayP6float3
#     0 bytes stack frame, 224 bytes spill stores, 600 bytes spill loads
# ptxas info    : Function properties for _Z14svm_eval_nodesP13KernelGlobalsP10ShaderDataP9PathState10ShaderTypei
#     0 bytes stack frame, 668 bytes spill stores, 592 bytes spill loads
# ptxas info    : Function properties for _Z15direct_emissionP13KernelGlobalsP10ShaderDataS2_P11LightSampleP9PathStateP3RayP8BsdfEvalPbf
#     0 bytes stack frame, 104 bytes spill stores, 168 bytes spill loads
# ptxas info    : Function properties for _Z15path_state_nextP13KernelGlobalsP9PathStatei
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z15rgb_ramp_lookupP13KernelGlobalsifbbi
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z16noise_turbulence6float3fi
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z17area_light_sample6float3PS_S_S_ffb
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z17lamp_light_sampleP13KernelGlobalsiff6float3P11LightSample
#     0 bytes stack frame, 4 bytes spill stores, 12 bytes spill loads
# ptxas info    : Function properties for _Z17shader_bssrdf_sumP10ShaderDataP6float3Pf
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z17svm_node_geometryP13KernelGlobalsP10ShaderDataPfjj
#     0 bytes stack frame, 8 bytes spill stores, 20 bytes spill loads
# ptxas info    : Function properties for _Z18background_map_pdfP13KernelGlobals6float3
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z18noise_musgrave_fBm6float3fff
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z18shader_bsdf_sampleP13KernelGlobalsP10ShaderDataffP8BsdfEvalP6float3P13differential3Pf
#     0 bytes stack frame, 380 bytes spill stores, 132 bytes spill loads
# ptxas info    : Function properties for _Z18shader_eval_volumeP13KernelGlobalsP10ShaderDataP9PathStateP11VolumeStacki13ShaderContext
#     0 bytes stack frame, 44 bytes spill stores, 60 bytes spill loads
# ptxas info    : Function properties for _Z18triangle_intersectP13KernelGlobalsP12Intersection6float3S3_jii
#     0 bytes stack frame, 12 bytes spill stores, 24 bytes spill loads
# ptxas info    : Function properties for _Z19camera_world_to_ndcP13KernelGlobalsP10ShaderData6float3
#     0 bytes stack frame, 8 bytes spill stores, 8 bytes spill loads
# ptxas info    : Function properties for _Z19indirect_backgroundP13KernelGlobalsP10ShaderDataP9PathStateP3Ray
#     0 bytes stack frame, 64 bytes spill stores, 56 bytes spill loads
# ptxas info    : Function properties for _Z19kernel_write_resultP13KernelGlobalsPfiP12PathRadiancefb
#     0 bytes stack frame, 36 bytes spill stores, 16 bytes spill loads
# ptxas info    : Function properties for _Z20direct_emissive_evalP13KernelGlobalsP10ShaderDataP11LightSampleP9PathState6float313differential3ff
#     0 bytes stack frame, 60 bytes spill stores, 92 bytes spill loads
# ptxas info    : Function properties for _Z20kernel_volume_shadowP13KernelGlobalsP10ShaderDataP9PathStateP3RayP6float3
#     0 bytes stack frame, 360 bytes spill stores, 320 bytes spill loads
# ptxas info    : Function properties for _Z20patch_map_find_patchP13KernelGlobalsiiff
#     0 bytes stack frame, 8 bytes spill stores, 8 bytes spill loads
# ptxas info    : Function properties for _Z20shader_emissive_evalP13KernelGlobalsP10ShaderData
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z21background_map_sampleP13KernelGlobalsffPf
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z21background_portal_pdfP13KernelGlobals6float3S1_iPb
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z21direction_to_panoramaP13KernelGlobals6float3
#     0 bytes stack frame, 8 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z21panorama_to_directionP13KernelGlobalsff
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z21shader_merge_closuresP10ShaderData
#     0 bytes stack frame, 0 bytes spill stores, 8 bytes spill loads
# ptxas info    : Function properties for _Z21shader_setup_from_rayP13KernelGlobalsP10ShaderDataPK12IntersectionPK3Ray
#     0 bytes stack frame, 120 bytes spill stores, 140 bytes spill loads
# ptxas info    : Function properties for _Z21svm_node_attr_bump_dxP13KernelGlobalsP10ShaderDataPf5uint4
#     0 bytes stack frame, 24 bytes spill stores, 104 bytes spill loads
# ptxas info    : Function properties for _Z21svm_node_attr_bump_dyP13KernelGlobalsP10ShaderDataPf5uint4
#     0 bytes stack frame, 24 bytes spill stores, 104 bytes spill loads
# ptxas info    : Function properties for _Z22BVH_bvh_intersect_hairP13KernelGlobalsPK3RayP12IntersectionjPjff
#     0 bytes stack frame, 164 bytes spill stores, 184 bytes spill loads
# ptxas info    : Function properties for _Z22indirect_lamp_emissionP13KernelGlobalsP10ShaderDataP9PathStateP3RayP6float3
#     0 bytes stack frame, 92 bytes spill stores, 148 bytes spill loads
# ptxas info    : Function properties for _Z22path_radiance_accum_aoP12PathRadianceP9PathState6float3S3_S3_S3_
#     0 bytes stack frame, 0 bytes spill stores, 28 bytes spill loads
# ptxas info    : Function properties for _Z23_shader_bsdf_multi_evalP13KernelGlobalsP10ShaderData6float3PfiP8BsdfEvalff
#     0 bytes stack frame, 36 bytes spill stores, 44 bytes spill loads
# ptxas info    : Function properties for _Z23kernel_volume_integrateP13KernelGlobalsP9PathStateP10ShaderDataP3RayP12PathRadianceP6float3Pjb
#     0 bytes stack frame, 1178 bytes spill stores, 1156 bytes spill loads
# ptxas info    : Function properties for _Z23subsurface_scatter_evalP10ShaderDataP13ShaderClosureffb
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z24BVH_bvh_intersect_motionP13KernelGlobalsPK3RayP12Intersectionj
#     0 bytes stack frame, 12 bytes spill stores, 8 bytes spill loads
# ptxas info    : Function properties for _Z24kernel_volume_stack_initP13KernelGlobalsP10ShaderDataPK9PathStatePK3RayP11VolumeStack
#     0 bytes stack frame, 152 bytes spill stores, 380 bytes spill loads
# ptxas info    : Function properties for _Z24kernel_write_data_passesP13KernelGlobalsPfP12PathRadianceP10ShaderDataiP9PathState6float3
#     0 bytes stack frame, 48 bytes spill stores, 248 bytes spill loads
# ptxas info    : Function properties for _Z24shader_setup_from_sampleP13KernelGlobalsP10ShaderData6float3S3_S3_iiiffffbi
#     0 bytes stack frame, 0 bytes spill stores, 8 bytes spill loads
# ptxas info    : Function properties for _Z25kernel_path_volume_bounceP13KernelGlobalsPjP10ShaderDataP6float3P9PathStateP12PathRadianceP3Ray
#     0 bytes stack frame, 140 bytes spill stores, 120 bytes spill loads
# ptxas info    : Function properties for _Z25motion_triangle_intersectP13KernelGlobalsP12Intersection6float3S3_fjii
#     0 bytes stack frame, 108 bytes spill stores, 120 bytes spill loads
# ptxas info    : Function properties for _Z25path_radiance_accum_lightP12PathRadianceP9PathState6float3P8BsdfEvalS3_fb
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z25primitive_attribute_floatP13KernelGlobalsPK10ShaderData19AttributeDescriptorPfS5_
#     0 bytes stack frame, 4 bytes spill stores, 4 bytes spill loads
# ptxas info    : Function properties for _Z26kernel_path_surface_bounceP13KernelGlobalsPjP10ShaderDataP6float3P9PathStateP12PathRadianceP3Ray
#     0 bytes stack frame, 52 bytes spill stores, 124 bytes spill loads
# ptxas info    : Function properties for _Z26primitive_attribute_float3P13KernelGlobalsPK10ShaderData19AttributeDescriptorP6float3S6_
#     0 bytes stack frame, 16 bytes spill stores, 16 bytes spill loads
# ptxas info    : Function properties for _Z26triangle_refine_subsurfaceP13KernelGlobalsP10ShaderDataPK12IntersectionPK3Ray
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z26volume_normalized_positionP13KernelGlobalsPK10ShaderData6float3
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z27indirect_primitive_emissionP13KernelGlobalsP10ShaderDatafif
#     0 bytes stack frame, 12 bytes spill stores, 8 bytes spill loads
# ptxas info    : Function properties for _Z27path_radiance_clamp_and_sumP13KernelGlobalsP12PathRadiance
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z28BVH_bvh_intersect_instancingP13KernelGlobalsPK3RayP12Intersectionj
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z28motion_triangle_shader_setupP13KernelGlobalsP10ShaderDataPK12IntersectionPK3Rayb
#     0 bytes stack frame, 112 bytes spill stores, 112 bytes spill loads
# ptxas info    : Function properties for _Z28noise_musgrave_multi_fractal6float3fff
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z28shader_setup_from_subsurfaceP13KernelGlobalsP10ShaderDataPK12IntersectionPK3Ray
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z29BVH_bvh_intersect_hair_motionP13KernelGlobalsPK3RayP12IntersectionjPjff
#     0 bytes stack frame, 160 bytes spill stores, 224 bytes spill loads
# ptxas info    : Function properties for _Z29noise_musgrave_hetero_terrain6float3ffff
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z29subd_triangle_attribute_floatP13KernelGlobalsPK10ShaderData19AttributeDescriptorPfS5_
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z29triangle_intersect_subsurfaceP13KernelGlobalsP22SubsurfaceIntersection6float3S3_iifPji
#     0 bytes stack frame, 12 bytes spill stores, 28 bytes spill loads
# ptxas info    : Function properties for _Z30kernel_path_subsurface_scatterP13KernelGlobalsP10ShaderDataS2_P12PathRadianceP9PathStatePjP3RayP6float3P22SubsurfaceIndirectRays
#     0 bytes stack frame, 286 bytes spill stores, 632 bytes spill loads
# ptxas info    : Function properties for _Z30subd_triangle_attribute_float3P13KernelGlobalsPK10ShaderData19AttributeDescriptorP6float3S6_
#     0 bytes stack frame, 252 bytes spill stores, 336 bytes spill loads
# ptxas info    : Function properties for _Z30subsurface_scatter_multi_setupP13KernelGlobalsP22SubsurfaceIntersectioniP10ShaderDataP9PathStateiP13ShaderClosureb
#     0 bytes stack frame, 64 bytes spill stores, 120 bytes spill loads
# ptxas info    : Function properties for _Z32_shader_bsdf_multi_eval_branchedP13KernelGlobalsP10ShaderData6float3P8BsdfEvalfb
#     0 bytes stack frame, 4 bytes spill stores, 28 bytes spill loads
# ptxas info    : Function properties for _Z32path_state_rng_light_terminationP13KernelGlobalsPjPK9PathState
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z33kernel_path_surface_connect_lightP13KernelGlobalsPjP10ShaderDataS3_6float3P9PathStateP12PathRadiance
#     0 bytes stack frame, 168 bytes spill stores, 256 bytes spill loads
# ptxas info    : Function properties for _Z34direction_to_equirectangular_range6float36float4
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z34object_fetch_transform_motion_testP13KernelGlobalsifP9Transform
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z34subsurface_scatter_multi_intersectP13KernelGlobalsP22SubsurfaceIntersectionP10ShaderDataP13ShaderClosurePjffb
#     0 bytes stack frame, 208 bytes spill stores, 224 bytes spill loads
# ptxas info    : Function properties for _Z35noise_musgrave_hybrid_multi_fractal6float3fffff
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z35noise_musgrave_ridged_multi_fractal6float3fffff
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z35path_branched_rng_light_terminationP13KernelGlobalsPjPK9PathStateii
#     0 bytes stack frame, 4 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z35shadow_blocked_transparent_all_loopP13KernelGlobalsP10ShaderDataP9PathStateiP3RayP12IntersectionjP6float3
#     0 bytes stack frame, 724 bytes spill stores, 916 bytes spill loads
# ptxas info    : Function properties for _Z42kernel_branched_path_surface_connect_lightP13KernelGlobalsPjP10ShaderDataS3_P9PathState6float3fP12PathRadiancei
#     0 bytes stack frame, 276 bytes spill stores, 840 bytes spill loads
# ptxas info    : Function properties for _Z6perlinfff
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z7svm_mix7NodeMixf6float3S0_
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z8svm_wave12NodeWaveType16NodeWaveProfiles6float3fff
#     0 bytes stack frame, 4 bytes spill stores, 4 bytes spill loads
# ptxas info    : Function properties for _Z9cellnoise6float3
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z9svm_brick6float3ffffffifi
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z9svm_magic6float3if
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Function properties for _Z9wireframeP13KernelGlobalsP10ShaderDatafiP6float3
#     0 bytes stack frame, 48 bytes spill stores, 48 bytes spill loads
# ptxas info    : Function properties for lgammaf
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas warning : Value of threads per SM for entry kernel_cuda_filter_finalize is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry kernel_cuda_filter_nlm_construct_gramian is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry kernel_cuda_filter_nlm_normalize is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry kernel_cuda_filter_nlm_update_output is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry kernel_cuda_filter_nlm_calc_weight is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry kernel_cuda_filter_nlm_blur is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry kernel_cuda_filter_nlm_calc_difference is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry kernel_cuda_filter_construct_transform is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry kernel_cuda_filter_combine_halves is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry kernel_cuda_filter_detect_outliers is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry kernel_cuda_filter_get_feature is out of range. .minnctapersm will be ignored
# ptxas warning : Value of threads per SM for entry kernel_cuda_filter_divide_shadow is out of range. .minnctapersm will be ignored
# ptxas info    : 0 bytes gmem
# ptxas info    : Compiling entry function 'kernel_cuda_filter_finalize' for 'sm_75'
# ptxas info    : Function properties for kernel_cuda_filter_finalize
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 64 registers, 436 bytes cmem[0]
# ptxas info    : Compiling entry function 'kernel_cuda_filter_nlm_construct_gramian' for 'sm_75'
# ptxas info    : Function properties for kernel_cuda_filter_nlm_construct_gramian
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 64 registers, 11264 bytes smem, 464 bytes cmem[0]
# ptxas info    : Compiling entry function 'kernel_cuda_filter_nlm_normalize' for 'sm_75'
# ptxas info    : Function properties for kernel_cuda_filter_nlm_normalize
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 9 registers, 388 bytes cmem[0]
# ptxas info    : Compiling entry function 'kernel_cuda_filter_nlm_update_output' for 'sm_75'
# ptxas info    : Function properties for kernel_cuda_filter_nlm_update_output
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 32 registers, 424 bytes cmem[0]
# ptxas info    : Compiling entry function 'kernel_cuda_filter_nlm_calc_weight' for 'sm_75'
# ptxas info    : Function properties for kernel_cuda_filter_nlm_calc_weight
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 32 registers, 392 bytes cmem[0]
# ptxas info    : Compiling entry function 'kernel_cuda_filter_nlm_blur' for 'sm_75'
# ptxas info    : Function properties for kernel_cuda_filter_nlm_blur
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 39 registers, 392 bytes cmem[0]
# ptxas info    : Compiling entry function 'kernel_cuda_filter_nlm_calc_difference' for 'sm_75'
# ptxas info    : Function properties for kernel_cuda_filter_nlm_calc_difference
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 44 registers, 416 bytes cmem[0]
# ptxas info    : Compiling entry function 'kernel_cuda_filter_construct_transform' for 'sm_75'
# ptxas info    : Function properties for kernel_cuda_filter_construct_transform
#     400 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 125 registers, 10240 bytes smem, 428 bytes cmem[0]
# ptxas info    : Compiling entry function 'kernel_cuda_filter_combine_halves' for 'sm_75'
# ptxas info    : Function properties for kernel_cuda_filter_combine_halves
#     104 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 52 registers, 404 bytes cmem[0]
# ptxas info    : Compiling entry function 'kernel_cuda_filter_detect_outliers' for 'sm_75'
# ptxas info    : Function properties for kernel_cuda_filter_detect_outliers
#     104 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 28 registers, 404 bytes cmem[0]
# ptxas info    : Compiling entry function 'kernel_cuda_filter_get_feature' for 'sm_75'
# ptxas info    : Function properties for kernel_cuda_filter_get_feature
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 19 registers, 425 bytes cmem[0]
# ptxas info    : Compiling entry function 'kernel_cuda_filter_divide_shadow' for 'sm_75'
# ptxas info    : Function properties for kernel_cuda_filter_divide_shadow
#     0 bytes stack frame, 0 bytes spill stores, 0 bytes spill loads
# ptxas info    : Used 21 registers, 441 bytes cmem[0]
#
# Blender quit
# src/tcmalloc.cc:283] Attempt to free invalid pointer 0x7f2da4c0e400
